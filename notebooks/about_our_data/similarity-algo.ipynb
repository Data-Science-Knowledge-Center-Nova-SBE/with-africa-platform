# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load the data from the uploaded file
file_path = '../../datasets/new_platform/about_our_data/about_data.xlsx'
indicator_df = pd.read_excel(file_path)
#indicator_df = ddt_df[['indicator_ddt_name', 'indicator_source', 'indicator_ddt_cat']].drop_duplicates()

# %%
indicator_df = indicator_df.reset_index()
indicator_df = indicator_df.drop(columns=['index'])
indicator_df['combined'] = indicator_df['indicator_ddt_name'] + ' ' + indicator_df['indicator_source'] #+ ' ' + str(indicator_df['indicator_year'])

# %%
print(indicator_df.head().to_markdown())
# Out:
# |    |   Unnamed: 0 | indicator_ddt_name                 | indicator_source   |   indicator_year | web_link                                                        | combined                                      |
# |---:|-------------:|:-----------------------------------|:-------------------|-----------------:|:----------------------------------------------------------------|:----------------------------------------------|
# |  0 |            1 | Average Length of Stay             | UNWTO              |             2022 | https://www.unwto.org/tourism-statistics/key-tourism-statistics | Average Length of Stay UNWTO                  |
# |  1 |            2 | Expenditure on Passenger Transport | UNWTO              |             2022 | https://www.unwto.org/tourism-statistics/key-tourism-statistics | Expenditure on Passenger Transport UNWTO      |
# |  2 |            3 | Expenditure on Passenger Transport | World Bank         |             2020 | https://data.worldbank.org/                                     | Expenditure on Passenger Transport World Bank |
# |  3 |            4 | Expenditure on Travel              | UNWTO              |             2022 | https://www.unwto.org/tourism-statistics/key-tourism-statistics | Expenditure on Travel UNWTO                   |
# |  4 |            5 | Expenditure on Travel              | World Bank         |             2020 | https://data.worldbank.org/                                     | Expenditure on Travel World Bank              |

# %%
def find_similar_indicators(indicator_name, df, top_n=3):
    # Vectorize the 'combined' column using TF-IDF
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(df['combined'])
    
    # Find the row index for the given indicator_name

    input_vec = vectorizer.transform([indicator_name])
    # Compute cosine similarity with all other rows
    cosine_similarities = cosine_similarity(input_vec, tfidf_matrix).flatten()
    
    # # Get the indices of the top n+1 similar indicators (excluding the input row itself)
    similar_indices = cosine_similarities.argsort()[-4:-1]
    
    # # Return the most similar indicators
    return df.iloc[similar_indices]
    #return cosine_similarities
# Example usage
input_indicator_name = indicator_df.iloc[4]['combined'] # Replace with your actual input

similar_indicators = find_similar_indicators(input_indicator_name, indicator_df)
similar_indicators
# Out:
#     Unnamed: 0                     indicator_ddt_name indicator_source  \
# 20          21  Total Expenditure on Outbound Tourism       World Bank
# 17          18   Total Expenditure on Inbound Tourism       World Bank
# 3            4                  Expenditure on Travel            UNWTO
#
#     indicator_year                                           web_link  \
# 20          2020.0                        https://data.worldbank.org/
# 17          2020.0                        https://data.worldbank.org/
# 3           2022.0  https://www.unwto.org/tourism-statistics/key-t...
#
#                                             combined
# 20  Total Expenditure on Outbound Tourism World Bank
# 17   Total Expenditure on Inbound Tourism World Bank
# 3                        Expenditure on Travel UNWTO

# %%
def obtain_sim_indic(row):
    indic = row['combined']
    sim_indics = find_similar_indicators(indic).indicator_ddt_name.tolist()
    row['sim_indic_1'] = sim_indics[0]
    row['sim_indic_2'] = sim_indics[1]
    row['sim_indic_3'] = sim_indics[2]

# %%
indicator_df['sim_indic_1'] = ""
indicator_df['sim_indic_2'] = ""
indicator_df['sim_indic_3'] = ""

# %%
for i, row in indicator_df.iterrows():
    sim_indics = find_similar_indicators(row['combined'], indicator_df).indicator_ddt_name.to_list()
    
    # Assign values directly to the DataFrame using 'i' (the index)
    indicator_df.loc[i, 'sim_indic_1'] = sim_indics[0]# if len(sim_indics) > 0 else None
    indicator_df.loc[i, 'sim_indic_2'] = sim_indics[1]# if len(sim_indics) > 1 else None
    indicator_df.loc[i, 'sim_indic_3'] = sim_indics[2] #if len(sim_indics) > 2 else None

# %%
indicator_df
# Out:
#     Unnamed: 0                  indicator_ddt_name          indicator_source  \
# 0            1              Average Length of Stay                     UNWTO
# 1            2  Expenditure on Passenger Transport                     UNWTO
# 2            3  Expenditure on Passenger Transport                World Bank
# 3            4               Expenditure on Travel                     UNWTO
# 4            5               Expenditure on Travel                World Bank
# ..         ...                                 ...                       ...
# 70          71        Ookla Speedtest Global Index                     Ookla
# 71          72          Africa Visa Openness Index  African Development Bank
# 72          73         Number of Conference Venues                      ICCA
# 73          74                  Number of Airlines                      IATA
# 74          75                            Language                  Wikidata
#
#     indicator_year                                           web_link  \
# 0           2022.0  https://www.unwto.org/tourism-statistics/key-t...
# 1           2022.0  https://www.unwto.org/tourism-statistics/key-t...
# 2           2020.0                        https://data.worldbank.org/
# 3           2022.0  https://www.unwto.org/tourism-statistics/key-t...
# 4           2020.0                        https://data.worldbank.org/
# ..             ...                                                ...
# 70          2024.0             https://www.speedtest.net/global-index
# 71          2023.0  https://www.visaopenness.org/fileadmin/uploads...
# 72          2024.0     https://portal.iccaworld.org/member-suppliers/
# 73          2024.0  https://www.iata.org/en/about/members/airline-...
# 74          2024.0         https://www.wikidata.org/wiki/Property:P37
#
#                                              combined  \
# 0                        Average Length of Stay UNWTO
# 1            Expenditure on Passenger Transport UNWTO
# 2       Expenditure on Passenger Transport World Bank
# 3                         Expenditure on Travel UNWTO
# 4                    Expenditure on Travel World Bank
# ..                                                ...
# 70                 Ookla Speedtest Global Index Ookla
# 71  Africa Visa Openness Index African Development...
# 72                   Number of Conference Venues ICCA
# 73                            Number of Airlines IATA
# 74                                  Language Wikidata
#
#                                           sim_indic_1  \
# 0   Official exchange rate (LCU per US$, period av...
# 1                Total Expenditure on Inbound Tourism
# 2                Total Expenditure on Inbound Tourism
# 3               Total Expenditure on Outbound Tourism
# 4               Total Expenditure on Outbound Tourism
# ..                                                ...
# 70                         Africa Visa Openness Index
# 71   WEF Travel and Tourism Development Index (Value)
# 72                         Total Number of Bed Places
# 73                         Total Number of Bed Places
# 74                                    Religious Sites
#
#                                         sim_indic_2  \
# 0                             Total Number of Rooms
# 1                             Expenditure on Travel
# 2                             Expenditure on Travel
# 3              Total Expenditure on Inbound Tourism
# 4              Total Expenditure on Inbound Tourism
# ..                                              ...
# 70                                 Corruption Index
# 71  WEF Travel and Tourism Development Index (Rank)
# 72                   Total Number of Establishments
# 73                   Total Number of Establishments
# 74                                         Currency
#
#                                 sim_indic_3
# 0            Total Number of Establishments
# 1        Expenditure on Passenger Transport
# 2        Expenditure on Passenger Transport
# 3                     Expenditure on Travel
# 4                     Expenditure on Travel
# ..                                      ...
# 70                       Global Peace Index
# 71  Total Travelers Originating From Africa
# 72                    Total Number of Rooms
# 73                    Total Number of Rooms
# 74                                  Capital
#
# [75 rows x 9 columns]

# %%
#joined_df_indic = pd.merge(ddt_df, indicator_df, on=['indicator_ddt_name', 'indicator_source', 'indicator_ddt_cat'])

# %%
indicator_df = indicator_df.drop(columns=['combined', 'Unnamed: 0'])

# %%
indicator_df.to_excel(file_path)

# %%
indicator_df.indicator_source.unique()
# Out:
# array(['UNWTO', 'World Bank', 'World Economic Forum', 'Wikidata',
#        'UNESCO', 'Vision of Humanity', 'Transparency International',
#        'Ookla', 'African Development Bank', 'ICCA', 'IATA'], dtype=object)
